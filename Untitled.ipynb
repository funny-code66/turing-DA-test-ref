# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
import json
from pandas.io.json import json_normalize
from wordcloud import WordCloud, STOPWORDS

# %%
df = pd.read_csv('cardio_base.csv')
df.columns
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  smoke
# 0          0  18393       2     168    62.0    110     80            1      0
# 1          1  20228       1     156    85.0    140     90            3      0
# 2          2  18857       1     165    64.0    130     70            3      0
# 3          3  17623       2     169    82.0    150    100            1      0
# 4          4  17474       1     156    56.0    100     60            1      0
# ...      ...    ...     ...     ...     ...    ...    ...          ...    ...
# 69995  99993  19240       2     168    76.0    120     80            1      1
# 69996  99995  22601       1     158   126.0    140     90            2      0
# 69997  99996  19066       2     183   105.0    180     90            3      0
# 69998  99998  22431       1     163    72.0    135     80            1      0
# 69999  99999  20540       1     170    72.0    120     80            2      0
#
# [70000 rows x 9 columns]

# %%
df.groupby('gender')['smoke'].mean()
# Out:
# gender
# 1    0.017856
# 2    0.218880
# Name: smoke, dtype: float64

# %%
0.218880/0.017856
# Out:
# 12.258064516129032

# %%
df.sort_values(by=['height'], ascending=False).iloc[0:700, 3].min()
# Out:
# 184

# %%
spear = []
for i in range(8):
    for j in range(i+1, 9):
        spear.append(df.iloc[:, [i, j]].corr(method="spearman"))
spear
# Out:
# [           id       age
#  id   1.000000  0.002682
#  age  0.002682  1.000000,
#                id    gender
#  id      1.000000  0.003506
#  gender  0.003506  1.000000,
#                id    height
#  id      1.000000 -0.001886
#  height -0.001886  1.000000,
#                id    weight
#  id      1.000000 -0.001292
#  weight -0.001292  1.000000,
#               id     ap_hi
#  id     1.000000  0.003258
#  ap_hi  0.003258  1.000000,
#               id     ap_lo
#  id     1.000000 -0.000238
#  ap_lo -0.000238  1.000000,
#                     id  cholesterol
#  id           1.000000     0.005706
#  cholesterol  0.005706     1.000000,
#               id     smoke
#  id     1.000000 -0.003697
#  smoke -0.003697  1.000000,
#               age    gender
#  age     1.000000 -0.020176
#  gender -0.020176  1.000000,
#               age    height
#  age     1.000000 -0.082292
#  height -0.082292  1.000000,
#               age    weight
#  age     1.000000  0.061559
# ...

# %%
list(zip(df.iloc[:, 2],df.iloc[:, 3]))
# Out:
# [(2, 168),
#  (1, 156),
#  (1, 165),
#  (2, 169),
#  (1, 156),
#  (1, 151),
#  (1, 157),
#  (2, 178),
#  (1, 158),
#  (1, 164),
#  (1, 169),
#  (2, 173),
#  (2, 165),
#  (1, 158),
#  (2, 181),
#  (2, 172),
#  (1, 170),
#  (1, 158),
#  (1, 154),
#  (2, 162),
#  (2, 163),
#  (1, 157),
#  (1, 158),
#  (2, 156),
#  (1, 170),
#  (1, 153),
#  (1, 156),
#  (1, 159),
#  (2, 166),
#  (2, 169),
#  (1, 155),
#  (1, 169),
#  (1, 159),
#  (1, 160),
#  (2, 173),
#  (1, 163),
#  (2, 175),
#  (1, 164),
#  (2, 162),
#  (1, 165),
#  (1, 157),
#  (1, 178),
#  (2, 171),
#  (2, 159),
#  (1, 154),
#  (1, 162),
#  (1, 162),
#  (2, 168),
#  (2, 175),
#  (1, 170),
#  (1, 160),
#  (1, 169),
#  (2, 166),
#  (1, 165),
#  (1, 152),
#  (2, 165),
#  (1, 171),
#  (1, 165),
#  (2, 172),
#  (1, 164),
#  (1, 159),
#  (2, 165),
#  (2, 187),
#  (1, 170),
#  (2, 169),
#  (1, 148),
#  (2, 170),
#  (2, 171),
#  (1, 152),
#  (1, 157),
#  (1, 155),
#  (2, 179),
#  (1, 156),
#  (1, 157),
#  (2, 180),
#  (1, 158),
# ...

# %%
df[df['height']<147.9389152].count()
# Out:
# id             896
# age            896
# gender         896
# height         896
# weight         896
# ap_hi          896
# ap_lo          896
# cholesterol    896
# smoke          896
# dtype: int64

# %%
df[df['height']>180.7788482].count()
# Out:
# id             1439
# age            1439
# gender         1439
# height         1439
# weight         1439
# ap_hi          1439
# ap_lo          1439
# cholesterol    1439
# smoke          1439
# dtype: int64

# %%
896+1439
# Out:
# 2335

# %%
2335/70000*100
# Out:
# 3.3357142857142854
